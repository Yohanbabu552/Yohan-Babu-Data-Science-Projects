# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_new=pd.read_excel("/content/Online Retail (1).xlsx")

# %%
df=df_new

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.drop(['Description'],inplace=True,axis=1)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 5227

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  401602.000000                         401602  401602.000000
# mean       12.182579  2011-07-10 12:08:08.129839872       3.474064
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-29 15:40:00       1.950000
# 75%        12.000000            2011-10-20 11:58:00       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       250.283248                            NaN      69.764209
#
#           CustomerID
# count  401602.000000
# mean    15281.172576
# min     12346.000000
# 25%     13939.000000
# 50%     15145.000000
# 75%     16784.000000
# max     18287.000000
# std      1714.002257

# %%
df.head()
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1    536365     71053         6 2010-12-01 08:26:00       3.39     17850.0
# 2    536365    84406B         8 2010-12-01 08:26:00       2.75     17850.0
# 3    536365    84029G         6 2010-12-01 08:26:00       3.39     17850.0
# 4    536365    84029E         6 2010-12-01 08:26:00       3.39     17850.0
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %%
sns.boxplot(x=df['Quantity'])
# Out:
# <Axes: xlabel='Quantity'>

# %%
sns.boxplot(x=df['UnitPrice'])
# Out:
# <Axes: xlabel='UnitPrice'>

# %%
from scipy.stats import zscore
df = df[(zscore(df['UnitPrice']) < 3)]

# %%
sns.boxplot(x=df['UnitPrice'])
# Out:
# <Axes: xlabel='UnitPrice'>

# %%
df = df[df['Quantity'] >= 0]

# %%
sns.boxplot(x=df['Quantity'])
# Out:
# <Axes: xlabel='Quantity'>

# %%
df = df[(zscore(df['Quantity']) < 3)]

# %%
sns.boxplot(x=df['Quantity'])
# Out:
# <Axes: xlabel='Quantity'>

# %%
df.head()
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1    536365     71053         6 2010-12-01 08:26:00       3.39     17850.0
# 2    536365    84406B         8 2010-12-01 08:26:00       2.75     17850.0
# 3    536365    84029G         6 2010-12-01 08:26:00       3.39     17850.0
# 4    536365    84029E         6 2010-12-01 08:26:00       3.39     17850.0
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %%
sns.histplot(df['Quantity'],kde=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.histplot(df['UnitPrice'],kde=True)
# Out:
# <Axes: xlabel='UnitPrice', ylabel='Count'>

# %%
sns.scatterplot(x='CustomerID',y='Quantity',data=df)
# Out:
# <Axes: xlabel='CustomerID', ylabel='Quantity'>

# %%
top_5_countries = df['Country'].value_counts().head(5).index
top_5_data = df[df['Country'].isin(top_5_countries)]

# %%
sns.barplot(x='Country',y='Quantity',data=top_5_data)
# Out:
# <Axes: xlabel='Country', ylabel='Quantity'>

# %%
top_5_countries = df['CustomerID'].value_counts().head(5).index
top_5_data = df[df['CustomerID'].isin(top_5_countries)]

# %%
sns.barplot(x='CustomerID',y='Quantity',data=top_5_data)
# Out:
# <Axes: xlabel='CustomerID', ylabel='Quantity'>

# %%
top_5_countries = df['StockCode'].value_counts().head(5).index
top_5_data = df[df['StockCode'].isin(top_5_countries)]

# %%
sns.barplot(x='StockCode',y='Quantity',data=top_5_data)
# Out:
# <Axes: xlabel='StockCode', ylabel='Quantity'>

# %%
top_5_countries = df['UnitPrice'].value_counts().head(5).index
top_5_data = df[df['UnitPrice'].isin(top_5_countries)]

# %%
sns.barplot(x='StockCode',y='UnitPrice',data=top_5_data)
# Out:
# <Axes: xlabel='StockCode', ylabel='UnitPrice'>

# %%
df
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 0         536365    85123A         6 2010-12-01 08:26:00       2.55
# 1         536365     71053         6 2010-12-01 08:26:00       3.39
# 2         536365    84406B         8 2010-12-01 08:26:00       2.75
# 3         536365    84029G         6 2010-12-01 08:26:00       3.39
# 4         536365    84029E         6 2010-12-01 08:26:00       3.39
# ...          ...       ...       ...                 ...        ...
# 541904    581587     22613        12 2011-12-09 12:50:00       0.85
# 541905    581587     22899         6 2011-12-09 12:50:00       2.10
# 541906    581587     23254         4 2011-12-09 12:50:00       4.15
# 541907    581587     23255         4 2011-12-09 12:50:00       4.15
# 541908    581587     22138         3 2011-12-09 12:50:00       4.95
#
#         CustomerID         Country
# 0          17850.0  United Kingdom
# 1          17850.0  United Kingdom
# 2          17850.0  United Kingdom
# ...

# %%
# Convert 'InvoiceDate' to datetime if not already
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Extract year and month, then aggregate Quantity by month
df['YearMonth'] = df['InvoiceDate'].dt.to_period('M')
monthly_data = df.groupby('YearMonth')['Quantity'].sum().reset_index()

# Convert 'YearMonth' back to string for easier plotting
monthly_data['YearMonth'] = monthly_data['YearMonth'].astype(str)

# Plot
sns.barplot(x='YearMonth', y='Quantity', data=monthly_data)
plt.xticks(rotation=45)  # Rotate month labels for better readability
plt.show()

# %%
sns.pairplot(df,hue='Country')
